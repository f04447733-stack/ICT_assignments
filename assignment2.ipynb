# %% [markdown]
# <a href="https://colab.research.google.com/github/f04447733-stack/ICT_assignments/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 2

# %%
for i in range(1,100):
  if i%3==0:
    print("Fizz")
  elif i%5==0:
      print("Buzz")
  elif i%5==0 and i%3==0:
    print("FizzBuzz")
  else:
    print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# Fizz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# Fizz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# Fizz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# Fizz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# Fizz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# Fizz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz

# %%
a = int(input("Enter units consumed"))
if a<=100:
  bill = a*5
  print("Total bill amount:",bill)
elif a<=200:
    bill = 100*5+((a-100)*7)
    print("Total bill amount:",bill)
else:
  bill = 100*5+100*7+(a-200)*10
  print("Total bill amount:",bill)
# Out:
# Enter units consumed245
# Total bill amount: 1650

# %%
y = "*"
for i in range(1,6):
  print(y*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
a = input("Enter  a number or string")
if a==a[::-1]:
  print("The given num or string is palindrome")
else:
    print("The given num or string is not palindrome")
# Out:
# Enter  a number or string121
# The given num or string is palindrome
